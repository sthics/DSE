# %% [markdown]
# ## Ambar Ghugre - 210968001

# %%
pip install -U gym
# Out:
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting gym-notices>=0.0.4
#   Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from gym) (4.11.3)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\user\anaconda3\lib\site-packages (from gym) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from gym) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gym) (3.7.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (PEP 517): started
#   Building wheel for gym (PEP 517): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827632 sha256=03af927ef153b0209762738d76b877d5c60ab22a74b3fdddce0efc65cb509466
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\af\2b\30\5e78b8b9599f2a2286a582b8da80594f654bf0e18d825a4405
# Successfully built gym
# Installing collected packages: gym-notices, gym
# Successfully installed gym-0.26.2 gym-notices-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "gym[classic_control]"
# Out:
# Requirement already satisfied: gym[classic_control] in c:\users\user\anaconda3\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\user\anaconda3\lib\site-packages (from gym[classic_control]) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from gym[classic_control]) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from gym[classic_control]) (4.11.3)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\user\anaconda3\lib\site-packages (from gym[classic_control]) (0.0.8)
# Collecting pygame==2.1.0
#   Downloading pygame-2.1.0-cp39-cp39-win_amd64.whl (4.8 MB)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gym[classic_control]) (3.7.0)
# Installing collected packages: pygame
# Successfully installed pygame-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "gymnasium[classic_control]"
# Out:
# Collecting gymnasium[classic_control]
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from gymnasium[classic_control]) (2.0.0)
# Collecting typing-extensions>=4.3.0
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from gymnasium[classic_control]) (4.11.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\anaconda3\lib\site-packages (from gymnasium[classic_control]) (1.24.3)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting pygame>=2.1.3
#   Downloading pygame-2.5.2-cp39-cp39-win_amd64.whl (10.8 MB)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium[classic_control]) (3.7.0)
# Installing collected packages: typing-extensions, farama-notifications, pygame, gymnasium
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.1.0
#     Uninstalling pygame-2.1.0:
#       Successfully uninstalled pygame-2.1.0
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1 pygame-2.5.2 typing-extensions-4.9.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.9.0 which is incompatible.

# %%
import gymnasium as gym
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics as stat

# %%
env = gym.make("CartPole-v1",render_mode = "human")

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.action_space
# Out:
# Discrete(2)

# %%
random_sample = env.action_space.sample()

# %%
print(random_sample)
# Out:
# 0

# %%
def plot_policy(final_rewards, policy_name:str=''):
    fig = plt.plot(range(len(final_rewards)), final_rewards)
    plt.grid()
    plt.title(policy_name + " Mean Reward {:.2f}, Std Reward {:.2f}".format(np.mean(final_rewards), np.min(final_rewards)))
    plt.ylabel('Cum Reward')
    plt.xlabel('Iteration')
    plt.ylim(0, max(final_rewards)*1.1)
    return fig

# %% [markdown]
# ## Theta policy

# %%
def test_policy(policy_func): #, n_scenario = N_scenario, max_actions = MAX_ACTIONS, verbose=False
    final_rewards = []
    episodes = 100
    for episode in range(1,episodes+1):
        
        obs = env.reset()  # reset to a random position
        done = False
        episode_rewards = 0
        angle=obs[0][2]
        
        while done == False:
            env.render()
            action = policy_func(angle)
            obs, reward, done, info,unknown = env.step(action)
            episode_rewards += reward
          
        final_rewards.append(episode_rewards)
        print("Episode :{} Score:{}".format(episode,episode_rewards))
    env.close()
    return final_rewards

# %%
def theta_policy(angle):
    return 0 if angle < 0 else 1

# %%
theta_rewards = test_policy(theta_policy)
# Out:
# Episode :1 Score:10.0
# Episode :2 Score:10.0
# Episode :3 Score:11.0
# Episode :4 Score:10.0
# Episode :5 Score:10.0
# Episode :6 Score:10.0
# Episode :7 Score:10.0
# Episode :8 Score:10.0
# Episode :9 Score:9.0
# Episode :10 Score:10.0
# Episode :11 Score:10.0
# Episode :12 Score:10.0
# Episode :13 Score:10.0
# Episode :14 Score:10.0
# Episode :15 Score:10.0
# Episode :16 Score:10.0
# Episode :17 Score:10.0
# Episode :18 Score:10.0
# Episode :19 Score:10.0
# Episode :20 Score:9.0
# Episode :21 Score:11.0
# Episode :22 Score:11.0
# Episode :23 Score:10.0
# Episode :24 Score:10.0
# Episode :25 Score:10.0
# Episode :26 Score:10.0
# Episode :27 Score:11.0
# Episode :28 Score:10.0
# Episode :29 Score:10.0
# Episode :30 Score:10.0
# Episode :31 Score:10.0
# Episode :32 Score:10.0
# Episode :33 Score:10.0
# Episode :34 Score:10.0
# Episode :35 Score:10.0
# Episode :36 Score:10.0
# Episode :37 Score:10.0
# Episode :38 Score:10.0
# Episode :39 Score:11.0
# Episode :40 Score:10.0
# Episode :41 Score:10.0
# Episode :42 Score:9.0
# Episode :43 Score:10.0
# Episode :44 Score:10.0
# Episode :45 Score:10.0
# Episode :46 Score:10.0
# Episode :47 Score:9.0
# Episode :48 Score:10.0
# Episode :49 Score:9.0
# Episode :50 Score:10.0
# Episode :51 Score:10.0
# Episode :52 Score:10.0
# Episode :53 Score:10.0
# Episode :54 Score:10.0
# Episode :55 Score:10.0
# Episode :56 Score:9.0
# Episode :57 Score:9.0
# Episode :58 Score:10.0
# Episode :59 Score:10.0
# Episode :60 Score:10.0
# Episode :61 Score:9.0
# Episode :62 Score:11.0
# Episode :63 Score:10.0
# Episode :64 Score:10.0
# Episode :65 Score:9.0
# Episode :66 Score:10.0
# Episode :67 Score:10.0
# Episode :68 Score:9.0
# Episode :69 Score:10.0
# Episode :70 Score:10.0
# Episode :71 Score:9.0
# Episode :72 Score:10.0
# Episode :73 Score:10.0
# Episode :74 Score:10.0
# Episode :75 Score:9.0
# Episode :76 Score:10.0
# Episode :77 Score:10.0
# Episode :78 Score:10.0
# Episode :79 Score:10.0
# Episode :80 Score:10.0
# Episode :81 Score:10.0
# Episode :82 Score:10.0
# Episode :83 Score:10.0
# Episode :84 Score:10.0
# Episode :85 Score:10.0
# Episode :86 Score:10.0
# Episode :87 Score:10.0
# Episode :88 Score:10.0
# Episode :89 Score:10.0
# Episode :90 Score:10.0
# Episode :91 Score:10.0
# Episode :92 Score:11.0
# Episode :93 Score:10.0
# Episode :94 Score:10.0
# Episode :95 Score:10.0
# Episode :96 Score:11.0
# Episode :97 Score:10.0
# Episode :98 Score:11.0
# Episode :99 Score:9.0
# Episode :100 Score:10.0

# %% [markdown]
# ## Omega policy

# %%
env = gym.make("CartPole-v1",render_mode = "human")

# %%
def test_policy(policy_func): #, n_scenario = N_scenario, max_actions = MAX_ACTIONS, verbose=False
    final_rewards = []
    episodes = 100
    for episode in range(1,episodes+1):
        
        obs = env.reset()  # reset to a random position
        done = False
        episode_rewards = 0
        omega=obs[0][3]
        
        while done == False:
            env.render()
            action = policy_func(omega)
            obs, reward, done, info,unknown = env.step(action)
            episode_rewards += reward
          
        final_rewards.append(episode_rewards)
        print("Episode :{} Score:{}".format(episode,episode_rewards))
    env.close()
    return final_rewards

# %%
def omega_policy(omega):
    return 1 if omega > 0 else 0

# %%
omega_rewards = test_policy(omega_policy)
# Out:
# Episode :1 Score:9.0
# Episode :2 Score:9.0
# Episode :3 Score:8.0
# Episode :4 Score:9.0
# Episode :5 Score:9.0
# Episode :6 Score:9.0
# Episode :7 Score:10.0
# Episode :8 Score:9.0
# Episode :9 Score:10.0
# Episode :10 Score:8.0
# Episode :11 Score:9.0
# Episode :12 Score:10.0
# Episode :13 Score:9.0
# Episode :14 Score:10.0
# Episode :15 Score:10.0
# Episode :16 Score:9.0
# Episode :17 Score:10.0
# Episode :18 Score:10.0
# Episode :19 Score:8.0
# Episode :20 Score:9.0
# Episode :21 Score:10.0
# Episode :22 Score:10.0
# Episode :23 Score:10.0
# Episode :24 Score:10.0
# Episode :25 Score:10.0
# Episode :26 Score:10.0
# Episode :27 Score:9.0
# Episode :28 Score:9.0
# Episode :29 Score:10.0
# Episode :30 Score:9.0
# Episode :31 Score:10.0
# Episode :32 Score:9.0
# Episode :33 Score:10.0
# Episode :34 Score:9.0
# Episode :35 Score:8.0
# Episode :36 Score:11.0
# Episode :37 Score:10.0
# Episode :38 Score:10.0
# Episode :39 Score:10.0
# Episode :40 Score:9.0
# Episode :41 Score:11.0
# Episode :42 Score:8.0
# Episode :43 Score:9.0
# Episode :44 Score:9.0
# Episode :45 Score:10.0
# Episode :46 Score:9.0
# Episode :47 Score:8.0
# Episode :48 Score:9.0
# Episode :49 Score:10.0
# Episode :50 Score:10.0
# Episode :51 Score:10.0
# Episode :52 Score:10.0
# Episode :53 Score:10.0
# Episode :54 Score:9.0
# Episode :55 Score:8.0
# Episode :56 Score:9.0
# Episode :57 Score:10.0
# Episode :58 Score:9.0
# Episode :59 Score:10.0
# Episode :60 Score:10.0
# Episode :61 Score:9.0
# Episode :62 Score:9.0
# Episode :63 Score:8.0
# Episode :64 Score:9.0
# Episode :65 Score:11.0
# Episode :66 Score:11.0
# Episode :67 Score:10.0
# Episode :68 Score:8.0
# Episode :69 Score:10.0
# Episode :70 Score:9.0
# Episode :71 Score:9.0
# Episode :72 Score:10.0
# Episode :73 Score:9.0
# Episode :74 Score:10.0
# Episode :75 Score:10.0
# Episode :76 Score:8.0
# Episode :77 Score:9.0
# Episode :78 Score:10.0
# Episode :79 Score:9.0
# Episode :80 Score:9.0
# Episode :81 Score:10.0
# Episode :82 Score:9.0
# Episode :83 Score:8.0
# Episode :84 Score:9.0
# Episode :85 Score:11.0
# Episode :86 Score:10.0
# Episode :87 Score:8.0
# Episode :88 Score:10.0
# Episode :89 Score:9.0
# Episode :90 Score:10.0
# Episode :91 Score:10.0
# Episode :92 Score:10.0
# Episode :93 Score:10.0
# Episode :94 Score:10.0
# Episode :95 Score:10.0
# Episode :96 Score:10.0
# Episode :97 Score:9.0
# Episode :98 Score:10.0
# Episode :99 Score:9.0
# Episode :100 Score:10.0

# %% [markdown]
# ## Cumulative rewards (based on steps) for theta policy

# %%
pt = plot_policy(theta_rewards, "Theta Policy")

# %% [markdown]
# ## Cumulative rewards (based on steps) for omega policy

# %%
pt = plot_policy(omega_rewards, "Omega Policy")

# %% [markdown]
# ##  Average rewards with standard deviation for theta policy

# %%
avg_theta=np.mean(theta_rewards)
stdev_theta=stat.stdev(theta_rewards)
print("Average rewards for theta policy: ", avg_theta)
print("Standard deviation for theta policy: ", stdev_theta)
# Out:
# Average rewards for theta policy:  9.96
# Standard deviation for theta policy:  0.46968719442418333

# %% [markdown]
# ##  Average rewards with standard deviation for omega policy

# %%
avg_omega=np.mean(omega_rewards)
stdev_omega=stat.stdev(omega_rewards)
print("Average rewards for omega policy: ", avg_omega)
print("Standard deviation for omega policy: ", stdev_omega)
# Out:
# Average rewards for omega policy:  9.44
# Standard deviation for omega policy:  0.7696253844067465
